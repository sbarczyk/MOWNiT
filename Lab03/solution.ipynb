# %% [markdown]
# # MOwNiT
#
# ## Laboratorium 3
#
# ## Interpolacja Lagrange'a

# %% [markdown]
# Przypomnijmy, że wielomianem interpolacyjnym Lagrange'a funkcji $f$ w puntach $x_1,...,x_n$ nazywamy wielomian dany wzorem
# $$W(x)=\sum_{j=1}^n f(x_j)\prod_{i\neq j}\frac{x-x_i}{x_j-x_i}.$$

# %% [markdown]
# Python posiada niezbyt numerycznie stabilną funkcję do znajdywania wielomianu interpolacyjnego Lagrange'a. Funkcja ta znajduje się w bibliotece `scipy.interpolate`.

# %%
import numpy as np
import scipy.interpolate as si

x = np.array([0, 1, 2])
y = np.sin(x)

poly = si.lagrange(x, y)

print(poly)
# Out:
#          2
# -0.3868 x + 1.228 x

# %%
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import Polynomial

xp=np.linspace(0,2,100)

plt.plot(xp,np.sin(xp),'b',label='$\sin x$')
plt.plot(xp,Polynomial(poly.coef[::-1])(xp),'r',label='Lagrange')
plt.scatter(x,y)
plt.legend()
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/qk/kz_wj6gd2_x88lqcpj7w9v8w0000gn/T/ipykernel_57571/3391280821.py:6: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(xp,np.sin(xp),'b',label='$\sin x$')

# %% [markdown]
# ### Zadanie 1. (1 pkt)
#
# Napisać własną implementację interpolacji wielomianowej stosując wprost wzór na wielomian interpolacyjny  Lagrange'a .  Przetestować swoją implementację na wylosowanych węzłach interpolacji w wybranym przedziale. Narysować wykres wielomianu interpolacyjnego w tym przedziale wraz z węzłami interpolacji.

# %%
import numpy as np
import matplotlib.pyplot as plt

def lagrange_interpolation(x_nodes, y_nodes, x):
    """Oblicza wartość wielomianu interpolacyjnego w punkcie x
       stosując wzór Lagrange’a.
    """
    n = len(x_nodes)
    L = 0
    for j in range(n):
        l_j = 1
        for i in range(n):
            if i != j:
                l_j *= (x - x_nodes[i]) / (x_nodes[j] - x_nodes[i])
        L += y_nodes[j] * l_j
    return L

# Interpolowany przedział oraz liczba węzłów interpolacji.
a, b = 0, 2 * np.pi
n_nodes = 10



# Losowanie i sortowanie węzłów w przedziale [a, b]
x_nodes = np.sort(np.random.uniform(a, b, n_nodes))

# Funkcja do interpolacji: f(x) = sin(x)
y_nodes = np.cos(x_nodes)

# Przygotowanie punktów do wykresu
x_plot = np.linspace(a, b, 400)
y_interpolated = np.array([lagrange_interpolation(x_nodes, y_nodes, xi) for xi in x_plot])
y_true = np.cos(x_plot)

# Rysowanie wykresu
plt.figure(figsize=(10, 6))
plt.plot(x_plot, y_interpolated, label="Interpolowany wielomian", color='blue')
plt.plot(x_nodes, y_nodes, 'o', label="Węzły interpolacji", color='red', markersize=8)
plt.plot(x_plot, y_true, '--', label="Funkcja cos(x)", color='green')
plt.title("Interpolacja Lagrange'a dla funkcji cos(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Zadanie 2. (2 pkt)
#
# Zaimplementować metodę Neville'a (metoda ilorazów róznicowych). Przetestować swoją implementację na wylosowanych węzłach interpolacji w wybranym przedziale. Narysować wykres wielomianu interpolacyjnego w tym przedziale wraz z węzłami interpolacji.

# %%
import numpy as np
import matplotlib.pyplot as plt

def neville_interpolation(x_nodes, y_nodes, x):
    """
    Oblicza wartość wielomianu interpolacyjnego w punkcie x
    metodą Neville’a.
    x_nodes - tablica węzłów interpolacji
    y_nodes - tablica odpowiadających im wartości funkcji
    x       - punkt, w którym obliczamy wartość wielomianu
    """
    n = len(x_nodes)
    Q = np.zeros((n, n))
    
    # Bazowy przypadek: P[i,i](x) = y[i]
    for i in range(n):
        Q[i, 0] = y_nodes[i]
    
    # Rekurencyjne obliczanie kolejnych wartości
    for j in range(1, n):
        for i in range(n - j):
            Q[i, j] = ((x - x_nodes[i+j]) * Q[i, j-1] + (x_nodes[i] - x) * Q[i+1, j-1]) \
          / (x_nodes[i] - x_nodes[i+j])
    return Q[0, n-1]



# Ustawienia przedziału i liczby węzłów interpolacji
a, b = -np.pi, np.pi
n_nodes = 10


# Losowanie i sortowanie węzłów w przedziale [a, b]
x_nodes = np.sort(np.random.uniform(a, b, n_nodes))
# Funkcja do interpolacji: sin(x)
y_nodes = np.sin(x_nodes)

# Przygotowanie punktów do wykresu
x_plot = np.linspace(a, b, 400)
y_interpolated = np.array([neville_interpolation(x_nodes, y_nodes, xi) for xi in x_plot])
y_true = np.sin(x_plot)

# Rysowanie wykresu
plt.figure(figsize=(10, 6))
plt.plot(x_plot, y_interpolated, label="Interpolowany wielomian (Neville)", color='blue')
plt.plot(x_nodes, y_nodes, 'o', label="Węzły interpolacji", color='red', markersize=8)
plt.plot(x_plot, y_true, '--', label="Funkcja sin(x)", color='green')
plt.title("Interpolacja metodą Neville'a")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Zadanie 3. (1 pkt)
#
# Porównać działanie metod z zadań 1 i 2 z funkcją `lagrange` ze scipy poprzez przedstawienie ich na wspólnym wykresie wraz z funkcją interpolowaną. Zbadać trzy różne funkcje:
# - wielomian
# - funkcję trygonometryczną
# - funkcję wykładniczą

# %%
from scipy.interpolate import lagrange as sp_lagrange
import numpy as np
import matplotlib.pyplot as plt

def f_pol(x):
    return 2*x**5 + 7*x**4 + 3*x**2 + 5

# Ustawienia przedziału i liczby węzłów interpolacji
a_pol, b_pol = -2, 1
n_nodes = 5
x_nodes_pol = np.sort(np.random.uniform(a_pol, b_pol, n_nodes))
print("Węzły interpolacji (x_nodes_pol):", x_nodes_pol)
y_nodes_pol = f_pol(x_nodes_pol)
x_plot_pol = np.linspace(a_pol, b_pol, 400)

# Obliczenia metodami (zakładamy, że funkcje lagrange_interpolation oraz neville_interpolation są już zdefiniowane)
y_lagrange_pol = np.array([lagrange_interpolation(x_nodes_pol, y_nodes_pol, xi) for xi in x_plot_pol])
y_neville_pol  = np.array([neville_interpolation(x_nodes_pol, y_nodes_pol, xi) for xi in x_plot_pol])
poly_sp_pol    = sp_lagrange(x_nodes_pol, y_nodes_pol)
y_sp_pol       = poly_sp_pol(x_plot_pol)

# Rysowanie wykresu
plt.figure(figsize=(10,6))
plt.plot(x_plot_pol, f_pol(x_plot_pol), '--', label='Funkcja oryginalna (f_pol(x))')
plt.plot(x_plot_pol, y_lagrange_pol, label='Metoda Lagrange')
plt.plot(x_plot_pol, y_neville_pol, label="Metoda Neville'a")
plt.plot(x_plot_pol, y_sp_pol, label='SciPy lagrange')
plt.plot(x_nodes_pol, y_nodes_pol, 'o', label='Węzły interpolacji')
plt.title('Interpolacja dla funkcji wielomianowej')
plt.xlabel('x')
plt.ylabel('f_pol(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Węzły interpolacji (x_nodes_pol): [-1.7049595  -1.49050874 -0.73667712  0.63442751  0.87366859]

# %%
from scipy.interpolate import lagrange as sp_lagrange
import numpy as np
import matplotlib.pyplot as plt

def f_exp(x):
    return np.exp(x)

# Ustawienia przedziału i liczby węzłów interpolacji
a_exp, b_exp = -1, 1
n_nodes = 4
x_nodes_exp = np.sort(np.random.uniform(a_exp, b_exp, n_nodes))
print("Węzły interpolacji (x_nodes_pol):", x_nodes_pol)
y_nodes_exp = f_exp(x_nodes_exp)
x_plot_exp = np.linspace(a_exp, b_exp, 400)

# Obliczenia metodami
y_lagrange_exp = np.array([lagrange_interpolation(x_nodes_exp, y_nodes_exp, xi) 
                             for xi in x_plot_exp])
y_neville_exp  = np.array([neville_interpolation(x_nodes_exp, y_nodes_exp, xi) 
                             for xi in x_plot_exp])
poly_sp_exp    = sp_lagrange(x_nodes_exp, y_nodes_exp)
y_sp_exp       = poly_sp_exp(x_plot_exp)

# Rysowanie wykresu
plt.figure(figsize=(10,6))
plt.plot(x_plot_exp, f_exp(x_plot_exp), '--', label='Funkcja oryginalna (exp(x))')
plt.plot(x_plot_exp, y_lagrange_exp, label='Metoda Lagrange')
plt.plot(x_plot_exp, y_neville_exp, label="Metoda Neville'a")
plt.plot(x_plot_exp, y_sp_exp, label='SciPy lagrange')
plt.plot(x_nodes_exp, y_nodes_exp, 'o', label='Węzły interpolacji')
plt.title('Interpolacja dla funkcji wykładniczej')
plt.xlabel('x')
plt.ylabel('f_exp(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Węzły interpolacji (x_nodes_pol): [-1.7049595  -1.49050874 -0.73667712  0.63442751  0.87366859]

# %%
from scipy.interpolate import lagrange as sp_lagrange

def f_trig(x):
    # Prostsza funkcja trygonometryczna: sin(x)
    return np.sin(x)

# Ustawienia przedziału i liczby węzłów interpolacji
a_trig, b_trig = -np.pi, np.pi
n_nodes = 8
np.random.seed(1)
x_nodes_trig = np.sort(np.random.uniform(a_trig, b_trig, n_nodes))
y_nodes_trig = f_trig(x_nodes_trig)
x_plot_trig = np.linspace(a_trig, b_trig, 400)

# Obliczenia metodami
y_lagrange_trig = np.array([lagrange_interpolation(x_nodes_trig, y_nodes_trig, xi) 
                            for xi in x_plot_trig])
y_neville_trig  = np.array([neville_interpolation(x_nodes_trig, y_nodes_trig, xi) 
                            for xi in x_plot_trig])
poly_sp_trig    = sp_lagrange(x_nodes_trig, y_nodes_trig)
y_sp_trig       = poly_sp_trig(x_plot_trig)

# Rysowanie wykresu
plt.figure(figsize=(10, 6))
plt.plot(x_plot_trig, f_trig(x_plot_trig), '--', 
         label='Funkcja oryginalna (sin(x))')
plt.plot(x_plot_trig, y_lagrange_trig, label='Metoda Lagrange')
plt.plot(x_plot_trig, y_neville_trig, label="Metoda Neville'a")
plt.plot(x_plot_trig, y_sp_trig, label='SciPy lagrange')
plt.plot(x_nodes_trig, y_nodes_trig, 'o', label='Węzły interpolacji')
plt.title('Interpolacja dla funkcji trygonometrycznej (sin(x))')
plt.xlabel('x')
plt.ylabel('f_trig(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Interpolacja Hermite'a

# %% [markdown]
# Interpolacja Hermite’a umożliwia znalezienie wielomianu interpolacyjnego zadanej funkcji w przypadku, gdy oprócz wartości funkcji w pewnych punktach $x_1,...,x_n$ dane są również wartości jej pochodnych, tzn. znamy
#
# $$f(x_{1}),f(x_{2}),\ldots ,f(x_{n})$$
#
# oraz
#
# $$f'(x_{1}),\ldots ,f^{(k_{1})}(x_{1}),f'(x_2),\ldots,f^{(k_2)}(x_2)\ldots ,f'(x_{n}),\ldots ,f^{(k_{n})}(x_{n})$$
#
# Jeżeli w danym punkcie $x_j$ znamy wyłącznie wartość funkcji, to punkt $(x_j,f(x_j))$ nazywamy *węzłem jednokrotnym*, natomiast jeżeli znamy wartości pochodnych aż do $k$-tej włącznie, to punkt $(x_j,f(x_j))$ nazywamy *węzłem $k+1$ krotnym*.

# %% [markdown]
# ### Algorytm - teoria

# %% [markdown]
# Konstruujemy macierz węzłów w taki sposób, że węzęł $k$-krotny powtarzamy dokładnie $k$ razy:

# %% [markdown]
# $$\left[\begin{array}{c}
# x_1&f(x_1)\\
# x_1&f(x_1)\\
# x_1&f(x_1)\\
# \vdots\\
# x_1&f(x_1)\\
# x_2&f(x_2)\\
# x_2&f(x_2)\\
# \vdots\\
# x_2&f(x_2)\\
# \vdots\\
# x_n&f(x_n)\\
# x_n&f(x_n)\\
# \vdots\\
# x_n&f(x_n)
# \end{array}\right]$$

# %% [markdown]
# Następnie uzupełniamy naszą macierz o kolejną kolumnę zawierającą *różnice dzielone pierwszego rzędu*$$f[x_{i-1},x_{i}]:=\frac{f(x_{i})-f(x_{i-1})}{x_{i}-x_{i-1}}.$$ Tam, gdzie nie możemy obliczyć różnicy dzielonej (obecny i poprzedni punkt jest taki sam) wstawiamy $$\frac{f'(x_i)}{1!}.$$

# %% [markdown]
# $$\left[\begin{array}{cc}
# x_1&f(x_1)&-\\
# x_1&f(x_1)&f'(x_1)\\
# x_1&f(x_1)&f'(x_1)\\
# \vdots&\vdots\\
# x_1&f(x_1)&f'(x_1)\\
# x_2&f(x_2)&f[x_1,x_2]\\
# x_2&f(x_2)&f'(x_2)\\
# \vdots&\vdots\\
# x_2&f(x_2)&f'(x_2)\\
# \vdots&\vdots\\
# x_n&f(x_n)&f[x_{n-1},x_n]\\
# x_n&f(x_n)&f'(x_n)\\
# \vdots&\vdots\\
# x_n&f(x_n)&f'(x_n)
# \end{array}\right]$$

# %% [markdown]
# W kolejnym kroku uzupełniamy macierz o kolumnę *różnic dzielonych drugiego rzędu* $$f[x_{i-2},x_{i-1},x_i]=\frac{f[x_{i-1},x_i]-f[x_{i-2},x_{i-1}]}{x_i-x_{i-2}}$$

# %% [markdown]
# Jeżeli $f[x_{i-1},x_i]$ lub $f[x_{i-2},x_{i-1}]$ nie istniała, to do wzoru wstawiamy zastępującą ją pochodną.

# %% [markdown]
# Jeżeli nie jesteśmy wstanie obliczyć różnicy dzielonej drugiego rzędu (dwa poprzednie punkty są takie same, jak aktualny), to wstawiamy $$\frac{f''(x_i)}{2!}.$$

# %% [markdown]
# $$\left[\begin{array}{ccc}
# x_1&f(x_1)&-&-\\
# x_1&f(x_1)&f'(x_1)&-\\
# x_1&f(x_1)&f'(x_1)&\frac{f''(x_1)}{2}\\
# \vdots&\vdots&\vdots\\
# x_1&f(x_1)&f'(x_1)&\frac{f''(x_1)}{2}\\
# x_2&f(x_2)&f[x_1,x_2]&f[x_1,x_1,x_2]\\
# x_2&f(x_2)&f'(x_2)&f[x_1,x_2,x_2]\\
# \vdots&\vdots&\vdots\\
# x_2&f(x_2)&f'(x_2)&\frac{f''(x_1)}{2}\\
# \vdots&\vdots&\vdots\\
# x_n&f(x_n)&f[x_{n-1},x_n]&f[x_{n-1},x_{n-1},x_n]\\
# x_n&f(x_n)&f'(x_n)&f[x_{n-1},x_n,x_n]\\
# \vdots&\vdots&\vdots\\
# x_n&f(x_n)&f'(x_n)&\frac{f''(x_1)}{2}
# \end{array}\right]$$

# %% [markdown]
# Kontynuujemy rekurencyjnie obliczając kolejne *różnice dzielone $k$-tego rzędu* $$f[x_{i-k},x_{i-k+1},...,x_i]=\frac{f[x_{i-k+1},...,x_i]-f[x_{i-k},x_{i-k+1},...,x_{i-1}]}{x_i-x_{i-k}}$$

# %% [markdown]
# pamiętając o zastąpieniu wyrażeń nieistniejących wyrażeniami z pochodnymi dzielonymi przez $(k-1)!$ a tam, gdzie mianownik byłby równy zero wstawiamy zamiast nich $$\frac{f^{(k)}(x_i)}{k!}$$.

# %% [markdown]
# Po zakończeniu algorytmu otrzymujemy macierz, która po opuszczeniu kolumny zawierającej $x_i$ jest macierzą  kwadratową

# %% [markdown]
# $$H=\left[\begin{array}{ccccc}
# f(x_1)&-&-&\cdots&-\\
# f(x_1)&f'(x_1)&-&\cdots&-\\
# f(x_1)&f'(x_1)&\frac{f''(x_1)}{2}&\cdots&-\\
# \vdots&\vdots&\vdots&\cdots&-\\
# f(x_1)&f'(x_1)&\frac{f''(x_1)}{2}&\cdots&-\\
# f(x_2)&f[x_1,x_2]&f[x_1,x_1,x_2]&\cdots&-\\
# f(x_2)&f'(x_2)&f[x_1,x_2,x_2]&\cdots&-\\
# \vdots&\vdots&\vdots&\cdots&-\\
# f(x_2)&f'(x_2)&\frac{f''(x_1)}{2}&\cdots&-\\
# \vdots&\vdots&\vdots&\cdots&-\\
# f(x_n)&f[x_{n-1},x_n]&f[x_{n-1},x_{n-1},x_n]&\cdots&-\\
# f(x_n)&f'(x_n)&f[x_{n-1},x_n,x_n]&\cdots&-\\
# \vdots&\vdots&\vdots&\cdots&-\\
# f(x_n)&f'(x_n)&\frac{f''(x_1)}{2}&\cdots&f[x_1,...,x_n]
# \end{array}\right]$$

# %% [markdown]
# Wielomian interpolacyjny Hermite'a ma postać $$W(x)=\sum _{i=1}^{m}a_{i}\prod _{j=1}^{i-1}(x-x_{j}),$$

# %% [markdown]
# gdzie współczynniki $a_i$ są wyrazami na przekątnej macierzy $H$ a $m$ jest liczbą węzłów liczoną wraz z ich krotnościami.

# %% [markdown]
# ### Przykład

# %% [markdown]
# Mamy dane

# %% [markdown]
# |x_i| f(x_i) |f'(x_i)|f''(x_i)|
# |-|-|-|-|
# |2 |4 |4 |2|
# |3 |9  |  |

# %% [markdown]
# Układamy macierz węzłów powtórzonych zgodnie z ich krotnością

# %% [markdown]
# $$\left[\begin{array}{c}
# 2&4\\
# 2&4\\
# 2&4\\
# 3&9
# \end{array}\right]$$

# %% [markdown]
# Uzupełniamy o różnice dzielone pierwszego rzędu (lub wartości pierwszej pochodnej)

# %% [markdown]
# $$\left[\begin{array}{ccc}
# 2&4&-\\
# 2&4&4\\
# 2&4&4\\
# 3&9&5
# \end{array}\right]$$

# %% [markdown]
# ...drugiego rzędu...

# %% [markdown]
# $$\left[\begin{array}{cccc}
# 2&4&-&-\\
# 2&4&4&-\\
# 2&4&4&1\\
# 3&9&5&1
# \end{array}\right]$$

# %% [markdown]
# ...trzeciego rzędu...

# %% [markdown]
# $$\left[\begin{array}{ccccc}
# 2&4&-&-&-\\
# 2&4&4&-&-\\
# 2&4&4&1&-\\
# 3&9&5&1&0
# \end{array}\right]$$

# %% [markdown]
# Otrzymujemy wielomian Hermite'a $$W(x)=4+4(x-2)+(x-2)(x-2)+0\cdot(x-2)(x-2)(x-2)$$

# %% [markdown]
# ### Algorytm - praktyka

# %% [markdown]
# Załóżmy, że mamy dane punkty $x_0,...,x_n$, wartości funkcji $y_0,...,y_n$ oraz wartości pierwszej pochodnej $p_0,...,p_n$.

# %% [markdown]
# #### START

# %% [markdown]
# Tworzymy macierz A wymiaru $(2n+1)\times(2n+1)$ wypełnioną zerami i zerowy wektor pomocniczy $b$ o długości $2n+1$.

# %% [markdown]
# #### Krok 1

# %% [markdown]
# Dla $i=0,...,n$ wykonujemy:

# %% [markdown]
# - $b_{2i}=x_i$
# - $b_{2i+1}=x_i$
# - $A_{2i,0}=y_i$
# - $A_{2i+1,0}=y_i$
# - $A_{2i+1,1}=p_i$
# - jeżeli $i\neq 0$ to $$A_{2i,1}=\frac{A_{2i,0}-A_{2i-1,0}}{b_{2i}-b_{2i-1}}$$

# %% [markdown]
# #### Krok 2

# %% [markdown]
# Dla $i=2,...,2n+1$ wykonujemy:

# %% [markdown]
# dla $j=2,...,i$ wykonujemy: $$A_{i,j}=\frac{A_{i,j-1}-A_{i-1,j-1}}{b_i-b_{i-j}}$$

# %% [markdown]
# #### Krok 3

# %% [markdown]
# Zwracamy wektor współczyników $A_{0,0},A_{1,1},...,A_{2n+1,2n+1}$ i konstuujemy wielomian $$W(x)=\sum _{i=0}^{2n+1}A_{i,i}\prod _{j=0}^{i-1}(x-x_{j}),$$

# %% [markdown]
# #### STOP

# %% [markdown]
# W `scikit.interpolation` funkcja `CubicHermiteSpline` znajduje wielomian interpolacyjny Hermite'a dla pierwszych pochodnych. W przypadku gdy dane są również wartości wyższych pochodnych wielomian interpolacyjny znajduje funkcja `BPoly.from_derivatives`.

# %%
hermite=si.BPoly.from_derivatives([2, 3], [[4, 4, 2], [9]] )

xpp=np.linspace(2,3,100)
plt.plot(xpp,hermite.__call__(xpp))

# %% [markdown]
# ### Zadanie 4. (3 pkt)
#
# Zaimplementować algorytm interpolacji Hermitte'a. Przetestować go na przykładowych danych wejściowych (mogą być powyższe) i porównać z działaniem funkcji z scipy.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicHermiteSpline

def hermite_interpolation(x, y, dy, x_eval):
    """
    Implementacja interpolacji Hermite'a przy użyciu tablicy różnic dzielonych Newtona.
    :param x: Węzły interpolacji
    :param y: Wartości funkcji w węzłach
    :param dy: Pochodne funkcji w węzłach
    :param x_eval: Punkty, w których oceniamy interpolację
    :return: Wartości interpolowanego wielomianu w punktach x_eval
    """
    n = len(x)
    z = np.zeros(2 * n)
    Q = np.zeros((2 * n, 2 * n))
    
    for i in range(n):
        z[2*i] = x[i]
        z[2*i+1] = x[i]
        Q[2*i, 0] = y[i]
        Q[2*i+1, 0] = y[i]
        Q[2*i+1, 1] = dy[i]
        if i != 0:
            Q[2*i, 1] = (Q[2*i, 0] - Q[2*i-1, 0]) / (z[2*i] - z[2*i-1])
    
    for i in range(2, 2*n):
        for j in range(2, i+1):
            Q[i, j] = (Q[i, j-1] - Q[i-1, j-1]) / (z[i] - z[i-j])
    
    def hermite_poly(t):
        result = 0
        for i in range(2*n):
            term = Q[i, i]
            product = 1.0
            for j in range(i):
                product *= (t - z[j])
            result += term * product
        return result
    
    return np.array([hermite_poly(t) for t in x_eval])

# Przykładowe dane dla bardziej skomplikowanej funkcji f(x) = sin(x) * e^(-0.2x) + 0.5 * cos(2x)
x = np.linspace(0, 2*np.pi, 7)
y = np.sin(x) * np.exp(-0.2*x) + 0.5 * np.cos(2*x)
dy = np.exp(-0.2*x) * (np.cos(x) - 0.2 * np.sin(x)) - np.sin(2*x)

x_eval = np.linspace(-0.5, 2*np.pi + 0.5, 300)
hermite_values = hermite_interpolation(x, y, dy, x_eval)

# Porównanie z scipy CubicHermiteSpline
spline = CubicHermiteSpline(x, y, dy)
scipy_values = spline(x_eval)

# Wykres porównawczy
plt.figure(figsize=(8, 6))
plt.plot(x_eval, scipy_values, label="scipy CubicHermiteSpline", linestyle=':', color='green')
plt.plot(x_eval, hermite_values, label="Interpolacja Hermite'a", linestyle='--', color='blue')
plt.plot(x_eval, np.sin(x_eval) * np.exp(-0.2*x_eval) + 0.5 * np.cos(2*x_eval), label="Oryginalna funkcja", linestyle='-', color='black')
plt.scatter(x, y, color='red', label='Punkty węzłowe')
plt.legend()
plt.xlabel('x')
plt.ylabel('sin(x) * e^(-0.2x) + 0.5 * cos(2x)')
plt.title("Interpolacja Hermite'a dla sin(x) * e^(-0.2x) + 0.5 * cos(2x)")
plt.grid()
plt.show()

#
# Dane do interpolacji Hermite'a
x_nodes = np.array([2, 3])
y_values = np.array([4, 9])
dy_values = np.array([4, 0])

# Punkty do oceny interpolacji
x_eval = np.linspace(2, 3, 100)
y_hermite = hermite_interpolation(x_nodes, y_values, dy_values, x_eval)

# Wykres interpolacji Hermite'a
plt.figure(figsize=(8, 5))
plt.plot(x_eval, y_hermite, label="Interpolacja Hermite'a", color='b')
plt.scatter(x_nodes, y_values, color='r', label="Węzły interpolacji")
plt.xlabel("x")
plt.ylabel("W(x)")
plt.title("Interpolacja Hermite'a - przykład 2.")
plt.legend()
plt.grid(True)

# %% [markdown]
# ### Zadanie 5. (1 pkt)
# Na przykładzie dowolnego wielomianu interpolacyjnego zobrazować graficznie i wyjaśnić czytelnikowi tzw. efekt Rungego (co za dużo, to niezdrowo).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange

# Definicja funkcji:
def f(x):
    return 1 / (1 + x**2)

# Ustawienia przedziału i liczby węzłów
a, b = -5, 5
n_nodes = 11
n_nodes_more = 20

# Wersja 1
x_nodes = np.linspace(a, b, n_nodes)
y_nodes = f(x_nodes)

# Wersja 2 - więcej węzłow
x_nodes_more = np.linspace(a, b, n_nodes_more)
y_nodes_more = f(x_nodes_more)

# Generowanie gęstej siatki do wykresu
x_plot = np.linspace(a, b, 400)

# Wyznaczenie wielomianu interpolacyjnego dla obu zestawów węzłów
poly = lagrange(x_nodes, y_nodes)
y_poly = poly(x_plot)

poly_more = lagrange(x_nodes_more, y_nodes_more)
y_poly_more = poly_more(x_plot)

# Rysowanie wykresów
plt.figure(figsize=(15, 6))

# Pierwszy subplot
plt.subplot(1, 2, 1)
plt.plot(x_plot, f(x_plot), 'g--', label=r'Funkcja Rungego: $\frac{1}{1+x^2}$')
plt.plot(x_plot, y_poly, 'b-', label='Wielomian interpolacyjny')
plt.plot(x_nodes, y_nodes, 'ro', label='Węzły interpolacji')
plt.title(f"Efekt Rungego - {n_nodes} węzłów")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)

# Drugi subplot - większa liczba węzłów
plt.subplot(1, 2, 2)
plt.plot(x_plot, f(x_plot), 'g--', label=r'Funkcja Rungego: $\frac{1}{1+x^2}$')
plt.plot(x_plot, y_poly_more, 'b-', label='Wielomian interpolacyjny')
plt.plot(x_nodes_more, y_nodes_more, 'ro', label='Węzły interpolacji')
plt.title(f"Efekt Rungego - {n_nodes_more} węzłów")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Efekt Rungego w Interpolacji Wielomianowej
#
# **Efekt Rungego** to zjawisko, w którym wielomian interpolacyjny wykazuje silne oscylacje, zwłaszcza na krańcach przedziału interpolacji. Problem ten pojawia się głównie przy równomiernie rozmieszczonych węzłach oraz przy użyciu wielomianów wysokiego stopnia.
#
#
# Rozważmy funkcję:
#
# $$
# f(x) = \frac{1}{1+x^2}.
# $$
#
# Interpolując tę funkcję na przedziale $[-5, 5]$ przy użyciu równomiernie rozmieszczonych węzłów, zauważamy, że:
#
# - **Węzły interpolacji** są wybierane równomiernie, czyli:
#
#   $$
#   x_i = -5 + i \cdot \Delta x, \quad i = 0, 1, \dots, n-1,
#   $$
#
#   gdzie $\Delta x = \frac{10}{n-1}$.
#
# - **Wielomian interpolacyjny** przechodzi dokładnie przez punkty $(x_i, f(x_i))$, ale na krańcach przedziału pojawiają się duże oscylacje – wielomian zaczyna „przeskakiwać” nad i pod wartością funkcji oryginalnej.
#
# ## Przyczyny efektu Rungego
#
# 1. **Wysoki stopień wielomianu:**
#    Dla $n$ węzłów interpolacyjnych wielomian ma stopień $n-1$. Wraz ze wzrostem $n$ wielomian staje się coraz bardziej skomplikowany, co może prowadzić do gwałtownych zmian wartości na krańcach przedziału.
#
# 2. **Równomierne rozmieszczenie węzłów:**
#    Równomierne rozmieszczenie nie zawsze jest optymalne dla funkcji, które wykazują duże zmiany w obrębie przedziału. Aby złagodzić efekt Rungego, często stosuje się węzły Czebyszewa, które są zagęszczone na krańcach przedziału.
#
# 3. **Zbieżność interpolacji:**
#    Chociaż wielomian interpolacyjny dokładnie przechodzi przez wszystkie węzły, nie zawsze zapewnia on jednostajną zbieżność do funkcji oryginalnej, szczególnie na krańcach przedziału.
#
# ## Podsumowanie
#
# - **Efekt Rungego** występuje, gdy interpolacja wielomianowa przy równomiernie rozmieszczonych węzłach prowadzi do niepożądanych oscylacji, zwłaszcza przy użyciu wielomianów wysokiego stopnia.
# - Przykładem jest funkcja
#
#   $$
#   f(x) = \frac{1}{1+x^2},
#   $$
#
#   gdzie wielomian interpolacyjny może znacznie odbiegać od funkcji oryginalnej na krańcach przedziału.
# - Aby zmniejszyć efekt Rungego, można zastosować węzły Czebyszewa lub techniki interpolacji oparte na sklejanych wielomianach.
#
# Takie podejście pokazuje, że „co za dużo, to niezdrowo” ma zastosowanie również w interpolacji – zbyt wysoki stopień wielomianu nie gwarantuje lepszej aproksymacji funkcji.
